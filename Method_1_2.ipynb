# %%
#IF SOMEBODY KNOWS HOW THE CLASS THING WORKS THAT WOULD BE SICK 

import os 
import urllib.request
import pandas as pd 
url = 'https://raw.githubusercontent.com/owid/energy-data/master/owid-energy-data.csv' 
filename = "data.csv"

def download(url,filename):
       
    if os.path.isfile(filename)==False:
        urllib.request.urlretrieve(url, filename)
        wtf=pd.read_csv(filename)
            
    else:
        wtf=pd.read_csv(filename)
        
    return wtf
        
df=(download(url,filename)
   [lambda x: x['year'] >= 1970])

# %%
df
# Out:
#            country  year iso_code  population           gdp  \
# 70     Afghanistan  1970      AFG  10752973.0  1.581223e+10
# 71     Afghanistan  1971      AFG  11015853.0  1.577051e+10
# 72     Afghanistan  1972      AFG  11286753.0  1.317055e+10
# 73     Afghanistan  1973      AFG  11575308.0  1.356863e+10
# 74     Afghanistan  1974      AFG  11869881.0  1.430911e+10
# ...            ...   ...      ...         ...           ...
# 21856     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10
# 21857     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 21858     Zimbabwe  2019      ZWE  15354606.0           NaN
# 21859     Zimbabwe  2020      ZWE  15669663.0           NaN
# 21860     Zimbabwe  2021      ZWE  15993525.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 70                         NaN                      NaN
# 71                         NaN                      NaN
# 72                         NaN                      NaN
# 73                         NaN                      NaN
# 74                         NaN                      NaN
# ...                        ...                      ...
# 21856                      NaN                      NaN
# 21857                      NaN                      NaN
# 21858                      NaN                      NaN
# 21859                      NaN                      NaN
# 21860                      NaN                      NaN
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 70                         NaN                  NaN                      NaN
# 71                         NaN                  NaN                      NaN
# 72                         NaN                  NaN                      NaN
# 73                         NaN                  NaN                      NaN
# 74                         NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# 21856                      NaN                  NaN                   21.693
# 21857                      NaN                  NaN                   25.910
# 21858                      NaN                  NaN                   24.748
# 21859                      NaN                  NaN                   22.336
# 21860                      NaN                  NaN                   23.760
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 70     ...               NaN                 NaN                   NaN
# 71     ...               NaN                 NaN                   NaN
# 72     ...               NaN                 NaN                   NaN
# 73     ...               NaN                 NaN                   NaN
# 74     ...               NaN                 NaN                   NaN
# ...    ...               ...                 ...                   ...
# 21856  ...             0.136                 NaN                   NaN
# 21857  ...             0.218                 NaN                   NaN
# 21858  ...             0.364                 NaN                   NaN
# 21859  ...             0.395                 NaN                   NaN
# 21860  ...             0.498                 NaN                   NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 70                      NaN               NaN                   NaN
# 71                      NaN               NaN                   NaN
# 72                      NaN               NaN                   NaN
# 73                      NaN               NaN                   NaN
# 74                      NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 21856                   NaN               NaN                   0.0
# 21857                   NaN               NaN                   0.0
# 21858                   NaN               NaN                   0.0
# 21859                   NaN               NaN                   0.0
# 21860                   NaN               NaN                   0.0
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 70                  NaN                     NaN              NaN
# 71                  NaN                     NaN              NaN
# 72                  NaN                     NaN              NaN
# 73                  NaN                     NaN              NaN
# 74                  NaN                     NaN              NaN
# ...                 ...                     ...              ...
# 21856               0.0                     NaN              0.0
# 21857               0.0                     NaN              0.0
# 21858               0.0                     NaN              0.0
# 21859               0.0                     NaN              0.0
# 21860               0.0                     NaN              0.0
#
#        wind_share_energy
# 70                   NaN
# 71                   NaN
# 72                   NaN
# 73                   NaN
# 74                   NaN
# ...                  ...
# 21856                NaN
# 21857                NaN
# 21858                NaN
# 21859                NaN
# 21860                NaN
#
# [13411 rows x 129 columns]

# %%
countries_list=df['country'].unique().tolist()
