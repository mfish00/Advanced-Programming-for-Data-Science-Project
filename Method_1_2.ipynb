# %%
#IF SOMEBODY KNOWS HOW THE CLASS THING WORKS THAT WOULD BE SICK 

import os 
import urllib.request
import pandas as pd 
url = 'https://github.com/owid/owid-datasets/blob/master/datasets/Agricultural%20total%20factor%20productivity%20(USDA)/Agricultural%20total%20factor%20productivity%20(USDA).csv' 
filename = "data.csv"

def download(url,filename):
       
    if os.path.isfile(filename)==False:
        urllib.request.urlretrieve(url, filename)
        wtf=pd.read_csv(filename)
            
    else:
        wtf=pd.read_csv(filename)
        
    return wtf
        
df=(download(url,filename))

# %%
df
# Out:
#            country  year iso_code  population           gdp  \
# 0      Afghanistan  1900      AFG   4832414.0           NaN
# 1      Afghanistan  1901      AFG   4879685.0           NaN
# 2      Afghanistan  1902      AFG   4935122.0           NaN
# 3      Afghanistan  1903      AFG   4998861.0           NaN
# 4      Afghanistan  1904      AFG   5063419.0           NaN
# ...            ...   ...      ...         ...           ...
# 21856     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10
# 21857     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 21858     Zimbabwe  2019      ZWE  15354606.0           NaN
# 21859     Zimbabwe  2020      ZWE  15669663.0           NaN
# 21860     Zimbabwe  2021      ZWE  15993525.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# ...

# %%
countries_list=df['country'].unique().tolist()
