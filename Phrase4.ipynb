# %% [markdown]
# Introduction: This code appears to be an implementation of a class Agros_class that has some methods to download and analyze agricultural data.

# %%
# %run Methods.ipynb
# Out:
# ...
#   Using cached download-0.3.5-py3-none-any.whl (8.8 kB)
# ...
#   Using cached scikit_learn-1.2.1-cp39-cp39-macosx_10_9_x86_64.whl (9.1 MB)
# ...
#   Using cached scipy-1.10.1-cp39-cp39-macosx_10_9_x86_64.whl (35.2 MB)
# ...
#   Using cached matplotlib-3.7.0-cp39-cp39-macosx_10_12_x86_64.whl (7.4 MB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# ...
#      |████████████████████████████████| 244 kB 4.4 MB/s eta 0:00:01
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ...

# %% [markdown]
# **<b>Initialization</b>:We choose Canada, Spain, Japan,firstly to check
# wheather or not exist in our dataset by using get_countries method.**

# %%
# Create an instance of the Agros_class
my_object = Agros_class()  
available_countries = my_object.get_countries()

canada_available = 'Canada' in available_countries
spain_available = 'Spain' in available_countries
japan_available = 'Japan' in available_countries

print(f"Is Canada available? {canada_available}")
print(f"Is Spain available? {spain_available}")
print(f"Is Japan available? {japan_available}")
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame
# Is Canada available? True
# Is Spain available? True
# Is Japan available? True

# %% [markdown]
# **<b>Next, we plot the output area of each country chosen using the (plot_output_area_chart) method: </b>**

# %%
Canada_output = Agros_class()
Spain_output = Agros_class()
Japan_output = Agros_class()
Canada_output.plot_output_area_chart('Canada')
Spain_output.plot_output_area_chart('Spain')
Japan_output.plot_output_area_chart('Japan')
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame

# %% [markdown]
# **<b></b>Among the differences are: For both Canada and Spain, output has been similar throughout these decades; However, Japan produced less during these decades than previous two countries, while it arrived at its peak in the 1990s relative to all other countries.**

# %% [markdown]
# <b>As a third step, we compare each country's output with its total output by using the (compare_output_total) method, as shown below: </b>

# %%
Canada_output.compare_output_total('Canada')
Spain_output.compare_output_total('Spain')
Japan_output.compare_output_total('Japan')

# %% [markdown]
# **<b>We find that :......</b> **

# %% [markdown]
# <b>Fourth Step</b>:How do the variables correlate with each other? Run your third method(plot_quantity_correlation) and briefly analyse it.

# %%
Variables_correlate = Agros_class()
Variables_correlate.plot_quantity_correlation()
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame

# %% [markdown]
# <b>Analysis</b>:Based on the generated heatmap, we can see that there are some variables that have a strong positive correlation with each other, such as quantity in agriland which includes animal,livestock,labor,machine...etc.On the other hand, quantity in fish output has much more lower correlation value to the land features.
