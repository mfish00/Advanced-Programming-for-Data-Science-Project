# %% [markdown]
# **Introduction:**
# The following showcases the Agros_class that we developed to download and analyze agricultural productivity data provided by the USDA.

# %%
import sys
sys.path.append("./Methods")
from methods import Agros_class

# %% [markdown]
# **Gapminder Method**

# %%
# Create an instance of the Agros_class
x=Agros_class()
x.gapminder(1980)
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %%
x.gapminder(2019)

# %% [markdown]
# The Gapminder chart above illustrates the relationship between the quantity of fertilizer used by a country (plotted on the x-axis) and the total output produced (plotted on the y-axis). As a third variable, we have selected the quantity of agricultural land, which represents the amount of pastures used for livestock grazing and croplands available in a country.
#
# At first glance, both charts shows a strong positive correlation between the amount of fertilizer used by a country and the output they produce. This result is expected, as fertilizers are additives designed to increase the productivity of crop yields. Additionally, the Gapminder charts indicate that an increase in the amount of agricultural land available has a positive effect on output, as the area of data points generally increases with an increase in output quantity. This rule, however, is not as strong, as we can observe several smaller countries generating greater outputs through the use of more fertilizers.
#
# When comparing 1980 with 2019, it is evident that the circles began to overlap in 2019 and were slightly larger than the previous year. This suggests a greater amount of pastures used in overall production. However, this change is relatively small when considering the time span of 40 years. One might expect more significant changes in the data during such a long period. Overllaping of the data may suggest that there is a limit to how much output can be produced even with increased fertilizer use and available agricultural land.

# %% [markdown]
# <b>Initialization</b>:
#
# In order to showcase the remaining methods of the Agros_class that we have created, we have chosen three countries: Canada, Japan, and Spain.
#
# We can begin by using the "get_countries" method to confirm that the selected countries are included in the dataset.

# %%
available_countries = x.get_countries()

canada_available = 'Canada' in available_countries
spain_available = 'Spain' in available_countries
japan_available = 'Japan' in available_countries

print(f"Is Canada present in the dataset? {canada_available}")
print(f"Is Spain present in the dataset? {spain_available}")
print(f"Is Japan present in the dataset? {japan_available}")
# Out:
# Is Canada present in the dataset? True
# Is Spain present in the dataset? True
# Is Japan present in the dataset? True

# %% [markdown]
# As seen above all three countries are present in the dataset so we can procedd with the analysis.

# %% [markdown]
# **Method to compare total output**

# %%
x.compare_output_total('Canada')
x.compare_output_total('Spain')
x.compare_output_total('Japan')

# %% [markdown]
# The line charts above provide a visual for the progession of our selected countries’ total output over time. As we can see both Canada and Spain have seen a steady increase in their total output levels over the years which can be explained by advances in pesticide and other factors boosting agricultural productivity. Japan on the other hand has seen a decrease in output since the 1990s as a result of Urbanization, with a reduction in land used for agriculture and a shortage of agricultural labor limiting their output capabilities.

# %% [markdown]
# **Area Chart of Outputs**

# %%
x.plot_output_area_chart('Canada')
x.plot_output_area_chart('Spain')
x.plot_output_area_chart('Japan')

# %% [markdown]
# This method breaks down the output of our selected countries into 3 categories that make up total output namely crop, animal, and fish yields. Taking a look at Canada and Spain we can see that crop yields account for more than half of total production with animal ouput accounting for the majority of the remaning total. Fish output is extremly marginal in Canada and Spain in its contributions to total output, but as can see it plays a larger role in Japan which in recent years has seen the combination of fish and animal outputs exceed its crop outputs which can again be explained by the rise in their urbanization levels.

# %% [markdown]
# **Correlation Matrix**

# %%
x=Agros_class()
x.plot_quantity_correlations()
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %% [markdown]
# The heatmap generated above displays the correlation between the all the quantity variables contained in the dataset, both output and input. It is clear that some variables are strongly positively correlated with each other. For example, the quantity of agricultural land, which includes variables such as animal, livestock, labor, and machinery, has a strong positive correlation with other land features.In contrast, the quantity of fish output has a much lower correlation value with the land features, indicating a weaker relationship between them.
#
#
# After conducting a quick analysis of the data, we can observe a positive correlation between the quantity variables and the output variables. In particular, countries with higher inputs of land, labor, and capital tend to have higher levels of crop, livestock, and fisheries production. This relationship is further supported by the fact that the correlation coefficients between the quantity variables and the output variables are all positive and statistically significant at the 0.01 level.

# %% [markdown]
# **Choropleth Method**

# %%
x=Agros_class()
x.choropleth(2000)
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %%
x=Agros_class()
x.choropleth(2019)
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %% [markdown]
# The continued pattern of the growth in Spain and Canada's agricultural output and the decline of Japan's is once again seen by visualizing TFP, or total factor productivity a measure of productive efficiency gauged by the amount of output that can be generated using a specific quantity of inputs, on a world map. Notably, total factor productivity in Japan was actually marginally higer than in spain in 2019 but if we take a look at the data we can see that this was simply a poor year for Spanish TFP.All three of our countries have seen an increase in TFP since 2000 but whereas Canada and Spain continue to grow Japan has stagnated in recent years. In other words Spain and Canada are on a trend of being able to produce more outputs with the same quantity of inputs while Japan is struggling to keep up with the continued improvements in effiency.
#
# In 2000, efficient agricultural countries were mainly located on the continent of Africa and South America.
# In 2019, we see an upward shift in lattitude, with the highest total factor productivity numbers being observed in Iceland, Sweden, Russia, Saudi Arabia, and Colombia.

# %% [markdown]
# **ARIMA Predictions**

# %%
x=Agros_class()
x.predictor('Canada', 'Spain', 'Japan')
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=336.030, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=341.125, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=342.641, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=338.101, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=342.749, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=328.939, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=333.962, Time=0.07 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=325.313, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=323.392, Time=0.07 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=325.233, Time=0.12 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=326.239, Time=0.24 sec
# ...

# %% [markdown]
# To attempt to get an idea of what Total Factor Produtivity might look like in the future we have fit an ARIMA model to our data. Our model predicts that all 3 countries will see linear growth in their TFP but once again we can see Japan lagging behind Canada and Spain in terms of projected growth despite having very similar TFP numbers at the end of our available data. Based on our predictions Spain and Canada will continue to see an increase in their Agriculutural output over the next 30 years while it continues to remain in question whether Japan will be able to turn around its decline in output.
