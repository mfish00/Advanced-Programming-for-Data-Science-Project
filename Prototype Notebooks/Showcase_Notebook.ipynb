# %% [markdown]
# **Introduction:**
# The following showcases the Agros_class that we developed to download and analyze agricultural productivity data provided by the USDA.

# %%
import sys
sys.path.append("./Methods")
from methods import Agros_class

# %% [markdown]
# To obtain an initial overview of the current state of global agriculture, we utilized the "gapminder" method previously defined in our dataset for the most recent year available, 2019.

# %%
x=Agros_class()
x.gapminder(2019)
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame

# %% [markdown]
# The Gapminder chart above illustrates the relationship between the quantity of fertilizer used by a country (plotted on the x-axis) and the total output produced (plotted on the y-axis). As a third variable, we have selected the quantity of agricultural land, which represents the amount of pastures used for livestock grazing and croplands available in a country.
#
# At first glance, the chart shows a strong positive correlation between the amount of fertilizer used by a country and the output they produce. This result is expected, as fertilizers are additives designed to increase the productivity of crop yields. Additionally, the Gapminder chart indicates that an increase in the amount of agricultural land available has a positive effect on output, as the area of data points generally increases with an increase in output quantity. This rule, however, is not as strong, as we can observe several smaller countries generating greater outputs through the use of more fertilizers.

# %% [markdown]
# <b>Initialization</b>:
# In order to showcase the remaining methods of the Agros_class that we have created, we have chosen three countries: Canada, Japan, and Spain.
#
# We can begin by using the "get_countries" method to confirm that the selected countries are included in the dataset.

# %%
# Create an instance of the Agros_class
my_object = Agros_class()  
available_countries = my_object.get_countries()

canada_available = 'Canada' in available_countries
spain_available = 'Spain' in available_countries
japan_available = 'Japan' in available_countries

print(f"Is Canada present in the dataset? {canada_available}")
print(f"Is Spain present in the dataset? {spain_available}")
print(f"Is Japan present in the dataset? {japan_available}")
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame
# Is Canada present in the dataset? True
# Is Spain present in the dataset? True
# Is Japan present in the dataset? True

# %% [markdown]
# ***

# %% [markdown]
# <b>Next</b>, we plot the output area of each country chosen using the "plot_output_area_chart" method:

# %%
Canada_output = Agros_class()
Spain_output = Agros_class()
Japan_output = Agros_class()
Canada_output.plot_output_area_chart('Canada')
Spain_output.plot_output_area_chart('Spain')
Japan_output.plot_output_area_chart('Japan')
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame

# %% [markdown]
# <b>Observations: </b>
#
# The area charts reveal that there are increasing trends since 1960, but Japan and Canada show decreasing trends in the past decade, unlike Spain which has steadily increased production and reached its peak in 2020. Spain had the lowest production output among the three countries in the early 1960s, but has steadily increased production since then. Japan's production output peaked at one point and has since experienced a decline each year, while Japan experienced the most rapid production growth among the three countries, which persisted until 1990.

# %% [markdown]
# ***

# %% [markdown]
# <b>As a third step,</b> we compare each country's output with its total output by using the "compare_output_total" method, as shown below:

# %%
Canada_output.compare_output_total('Canada')
Spain_output.compare_output_total('Spain')
Japan_output.compare_output_total('Japan')

# %% [markdown]
# <b>We find that :</b>
#
# Upon comparing the three countries, it is evident that Spain's total agricultural production is on track to surpass that of Canada, while Japan is expected to have the lowest production output. This trend may be attributed to Japan's relatively small land area and high level of urbanization, which could limit its potential for agricultural output.

# %% [markdown]
# ***

# %% [markdown]
# <b> In Fourth Step,</b> we analyzed the correlation between variables using the "plot_quantity_correlation" method.

# %%
Variables_correlate = Agros_class()
Variables_correlate.plot_quantity_correlation()
# Out:
# File already exists, skipping download
# Data loaded successfully into a Pandas DataFrame

# %% [markdown]
# <b>Analysis:</b>
#
# Based on the generated heatmap, it is clear that some variables are strongly positively correlated with each other. For example, the quantity of agricultural land, which includes variables such as animal, livestock, labor, and machinery, has a strong positive correlation with other land features.
#
# In contrast, the quantity of fish output has a much lower correlation value with the land features, indicating a weaker relationship between them.

# %% [markdown]
# ---

# %% [markdown]
# <b>After conducting a quick analysis of the data</b>,  we can observe a positive correlation between the quantity variables and the output variables. In particular, countries with higher inputs of land, labor, and capital tend to have higher levels of crop, livestock, and fisheries production. This relationship is further supported by the fact that the correlation coefficients between the quantity variables and the output variables are all positive and statistically significant at the 0.01 level.
