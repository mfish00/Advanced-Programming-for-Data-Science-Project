# %% [markdown]
# Introduction: The following notebook presents final analysis of with agricultural productivity data provided by the USDA, along with the agricultural output of multiple countries with agricultural productivity.

# %%
import sys
sys.path.append("./Methods")
from methods import Agros_class
# Out:
# Requirement already satisfied: pmdarima in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: urllib3 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: scipy>=1.3.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: pandas>=0.19 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: joblib>=0.11 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.4)
# Requirement already satisfied: download in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (0.3.5)
# Requirement already satisfied: six in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from download) (1.16.0)
# Requirement already satisfied: tqdm in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from download) (4.64.0)
# Requirement already satisfied: requests in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from download) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from requests->download) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from requests->download) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from requests->download) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from requests->download) (1.26.9)
# Requirement already satisfied: statsmodels in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: patsy>=0.5.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: scipy>=1.3 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: packaging>=21.3 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: scikit-learn in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: scipy in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: matplotlib in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.7.0)
# Requirement already satisfied: six>=1.5 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: geopandas in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: shapely>=1.7 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: packaging in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pandas>=1.0.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: fiona>=1.8 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.9.1)
# Requirement already satisfied: cligj>=0.5 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: click-plugins>=1.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: click~=8.0 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: setuptools in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (61.2.0)
# Requirement already satisfied: munch>=2.3.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: six in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/juliabak/opt/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)

# %%
x=Agros_class()
x.gapminder(1980)
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %%
x.gapminder(2019)

# %% [markdown]
# The Gapminder chart above illustrates the relationship between the quantity of fertilizer used by a country (plotted on the x-axis) and the total output produced (plotted on the y-axis). As a third variable, we have selected the quantity of agricultural land, which represents the amount of pastures used for livestock grazing and croplands available in a country.
#
# At first glance, both charts shows a strong positive correlation between the amount of fertilizer used by a country and the output they produce. This result is expected, as fertilizers are additives designed to increase the productivity of crop yields. Additionally, the Gapminder charts indicate that an increase in the amount of agricultural land available has a positive effect on output, as the area of data points generally increases with an increase in output quantity. This rule, however, is not as strong, as we can observe several smaller countries generating greater outputs through the use of more fertilizers.
#
# When comparing 1980 with 2019, it is evident that the circles began to overlap in 2019 and were slightly larger than the previous year. This suggests a greater amount of pastures used in overall production. However, this change is relatively small when considering the time span of 40 years. One might expect more significant changes in the data during such a long period. Overllaping of the data may suggest that there is a limit to how much output can be produced even with increased fertilizer use and available agricultural land.

# %%
# Create an instance of the Agros_class
my_object = Agros_class()  
available_countries = my_object.get_countries()

canada_available = 'Canada' in available_countries
spain_available = 'Spain' in available_countries
japan_available = 'Japan' in available_countries

print(f"Is Canada present in the dataset? {canada_available}")
print(f"Is Spain present in the dataset? {spain_available}")
print(f"Is Japan present in the dataset? {japan_available}")
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame
# Is Canada present in the dataset? True
# Is Spain present in the dataset? True
# Is Japan present in the dataset? True

# %% [markdown]
# By concentrating on Spain, Canada, and Japan, we will explore the development of agriculture, based on their unique characteristics, which could provide interesting and diverse outcomes. First, we will compare the total output of each country to have a better reference.

# %%
Canada_output = Agros_class()
Spain_output = Agros_class()
Japan_output = Agros_class()

Canada_output.compare_output_total('Canada')
Spain_output.compare_output_total('Spain')
Japan_output.compare_output_total('Japan')
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %% [markdown]
# The scatter charts presented above offer a distinct visual indication of Japan's divergence from the expected pattern, while Canada and Spain demonstrate comparable agricultural production patterns over time, with Spain taking the lead. Despite a substantial decrease in 1995, Spain's agricultural production still remains the highest. This may be due to the favorable climate conditions for agriculture in Spain. Conversely, Japan's limited land area and high urbanization levels may impact its agricultural output potential.

# %%
Canada_output.plot_output_area_chart('Canada')
Spain_output.plot_output_area_chart('Spain')
Japan_output.plot_output_area_chart('Japan')

# %% [markdown]
# Breaking down the overall production into smaller categories, a similar pattern as above is noticeable. In addition, the predominant use of pasture in each country is for livestock feed.

# %%
Variables_correlate = Agros_class()
Variables_correlate.plot_quantity_correlation()
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %% [markdown]
# Based on the generated heatmap, it is clear that some variables are strongly positively correlated with each other. For example, the quantity of agricultural land, which includes variables such as animal, livestock, labor, and machinery, has a strong positive correlation with other land features.In contrast, the quantity of fish output has a much lower correlation value with the land features, indicating a weaker relationship between them.
#
# After conducting a quick analysis of the data, we can observe a positive correlation between the quantity variables and the output variables. In particular, countries with higher inputs of land, labor, and capital tend to have higher levels of crop, livestock, and fisheries production. This relationship is further supported by the fact that the correlation coefficients between the quantity variables and the output variables are all positive and statistically significant at the 0.01 level.

# %%
x = Agros_class()
x.choropleth(2000)
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %%
x = Agros_class()
x.choropleth(2019)
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame

# %% [markdown]
# The scatter plot pattern is confirmed by visualizing TFP on a world map. Notably, agriculture in Japan was significantly smaller in 2019, whereas the opposite was observed in Canada and Spain.
#
# In 2000, agricultural countries were mainly located on the continent of Africa and South America.
# In 2019, the global trend switfs upward trajectory, with the largest agriculture output observed in Iceland, Sweden, Russia, Saudi Arabia, and Colombia.

# %%
x = Agros_class()
x.predictor('Canada', 'Spain', 'Japan')
# Out:
# Agri File already exists, skipping download
# Geo File already exists, skipping download
# Agri Data loaded successfully into a Pandas DataFrame
# Geo Data loaded successfully into a GeoPandas DataFrame
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=336.030, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=341.125, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=342.641, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=338.101, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=342.749, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=328.939, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=333.962, Time=0.01 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=325.313, Time=0.03 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=323.392, Time=0.02 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=325.233, Time=0.03 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=326.239, Time=0.06 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=338.204, Time=0.01 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0] intercept
# Total fit time: 0.260 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=340.577, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=365.530, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=344.890, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=338.633, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=366.323, Time=0.01 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=340.601, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=341.955, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=356.413, Time=0.01 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 0.112 seconds
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=220.250, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=220.997, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=220.036, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=219.241, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=240.030, Time=0.01 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=220.473, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=241.262, Time=0.01 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 0.097 seconds

# %% [markdown]
# ARIMA's projections for the next few years show that agriculture will continue to grow in selected countries.
